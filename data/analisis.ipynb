# %%
import pandas as pd
import json

# %%
restaurantes = pd.read_csv("restaurantes.csv")

# %%
display(restaurantes.head())
restaurantes["service_link"].describe()
# Out:
#                  name    service  latitude  longitude  address         zone  \
# 0  Simonetta Pizzería  Uber Eats       NaN        NaN      NaN  Providencia
# 1      Little Caesars  Uber Eats       NaN        NaN      NaN  Providencia
# 2             Waldo's  Uber Eats       NaN        NaN      NaN  Providencia
# 3        Big O' Pizza  Uber Eats       NaN        NaN      NaN  Providencia
# 4   Tropera Drugstore  Uber Eats       NaN        NaN      NaN  Providencia
#
#                                         service_link  image
# 0  https.www.ubereats.com/cl-en/store/simonetta-p...    NaN
# 1  https.www.ubereats.com/cl-en/store/little-caes...    NaN
# 2  https.www.ubereats.com/cl-en/store/waldos-prov...    NaN
# 3  https.www.ubereats.com/cl-en/store/big-o-pizza...    NaN
# 4  https.www.ubereats.com/cl-en/store/tropera-dru...    NaN
# count                                                  2923
# unique                                                 1348
# ...
